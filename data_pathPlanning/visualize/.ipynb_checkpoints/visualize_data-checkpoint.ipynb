# %%
import  numpy  as  np
import  pandas  as  pd
from  ast  import  literal_eval

in_file = '../data_autonomous/logger.csv'
sample = pd.read_csv(in_file, sep=',')

sample.head()
# Out:
#           784.6001 1135.571 0 -0.02359831 -0.9997216
# 0  815.2679 1134.93 30.6744785308838 -0.01099479 ...
# 1  844.6398 1134.911 60.0463714599609 -0.00204837...
# 2  875.0436 1134.808 90.4504146575928 -0.00184786...
# 3  905.283 1134.799 120.689735412598 0.004131136 ...
# 4  934.9677 1135.055 150.375551223755 0.05904382 ...

# %%
sample.describe()
# Out:
#                  x            y            s            d          yaw  \
# count  4751.000000  4751.000000  4751.000000  4751.000000  4751.000000
# mean   1926.000119  2189.034932  2313.771355     5.866989   127.647291
# std     407.028569   736.868762  1109.802379     1.486594    88.051837
# min     909.480000  1128.670000   124.834000     1.656960     0.000000
# 25%    1673.705000  1387.905000  1447.950000     5.894705    77.591700
# 50%    2100.260000  2330.700000  2410.900000     6.011460    88.972400
# 75%    2235.775000  2951.320000  3206.790000     6.116355   180.786000
# max    2339.480000  3005.740000  4280.380000    10.277900   359.865000
#
#              speed
# count  4751.000000
# mean     48.129860
# std       6.494374
# min       0.000000
# 25%      49.364500
# 50%      49.417000
# 75%      49.446000
# max      49.537700

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.image as mpimg
# %matplotlib inline

waypoint_file = "../data_autonomous/highway_map.csv"
logger_file = "../data_autonomous/logger.csv"

with open(waypoint_file) as f:
    x_waypoint = []
    y_waypoint = []
    count = 0
    for line in f:
        if count > 0:
            data = line.split(' ')
            x_waypoint.append(float(data[0]))
            y_waypoint.append(float(data[1]))
        count += 1

with open(logger_file) as f:
    x_path = []
    y_path = []
    count = 0
    for line in f:
        if count > 0:
            data = line.split(',')
            x_path.append(float(data[1]))
            y_path.append(float(data[2]))
        count += 1
        
x_start = [ x_path[0] ]
y_start = [ y_path[0] ]

x_current = [ x_path[len(x_path)-1] ]
y_current = [ y_path[len(y_path)-1] ]

# %%
plt.rcParams["figure.figsize"] = [16, 16]
p1 = plt.plot(x_path, y_path, 'b', lw=1.0)
p2 = plt.plot(x_waypoint, y_waypoint, 'go', ms=5.0)
p3 = plt.plot(x_start, y_start, 'yo', ms=5.0)
p4 = plt.plot(x_current, y_current, 'ro', ms=5.0)

plt.title('Track 1 Map')
plt.xlabel("X", fontsize=10)
plt.ylabel("Y", fontsize=10)

plt.legend((p1[0],p2[0], p3[0], p4[0]), ('outer lane path','Provided Waypoints', 'Starting Position','End Position'))
plt.show()

# %%
#get angle of car
with open(logger_file) as f:
    angle = []
    count = 0
    for line in f:
        if count > 0:
            data = line.split(',')
            angle.append(float(data[5]))
        count += 1

plt.rcParams["figure.figsize"] = [16, 8]       
plt.hist(angle)
plt.title("The angle frequency for the car")
plt.xlabel("Angle of Car (degrees)")
plt.ylabel("Frequency")
plt.show()

# %%
#get angle of car
with open(logger_file) as f:
    angle = []
    count = 0
    for line in f:
        if count > 0:
            data = line.split(',')
            angle.append(float(data[6]))
        count += 1

plt.rcParams["figure.figsize"] = [16, 8]       
plt.plot(angle)
plt.title("Speed of the Car")
plt.xlabel("Point on the Track")
plt.ylabel("Speed")
plt.show()
